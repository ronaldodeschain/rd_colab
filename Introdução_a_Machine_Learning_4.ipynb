# %% [markdown]
# <a href="https://colab.research.google.com/github/ronaldodeschain/rd_colab/blob/main/Introdu%C3%A7%C3%A3o_a_Machine_Learning_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

uri = "https://gist.githubusercontent.com/guilhermesilveira/4d1d4a16ccbf6ea4e0a64a38a24ec884/raw/afd05cb0c796d18f3f5a6537053ded308ba94bf7/car-prices.csv"
dados = pd.read_csv(uri)
dados.head()
# Out:
#    Unnamed: 0  mileage_per_year  model_year      price sold
# 0           0             21801        2000   30941.02  yes
# 1           1              7843        1998   40557.96  yes
# 2           2              7109        2006   89627.50   no
# 3           3             26823        2015   95276.14   no
# 4           4              7935        2014  117384.68  yes

# %%
a_renomear = {
    'mileage_per_year': 'milhas_por_ano',
    'model_year': 'ano_do_modelo',
    'price': 'preco',
    'sold' : 'vendido'

}
dados = dados.rename(columns = a_renomear)

# %%
dados.head()
# Out:
#    Unnamed: 0  milhas_por_ano  ano_do_modelo      preco vendido
# 0           0           21801           2000   30941.02     yes
# 1           1            7843           1998   40557.96     yes
# 2           2            7109           2006   89627.50      no
# 3           3           26823           2015   95276.14      no
# 4           4            7935           2014  117384.68     yes

# %%
dados.head()
# Out:
#    Unnamed: 0  milhas_por_ano  ano_do_modelo      preco vendido
# 0           0           21801           2000   30941.02     yes
# 1           1            7843           1998   40557.96     yes
# 2           2            7109           2006   89627.50      no
# 3           3           26823           2015   95276.14      no
# 4           4            7935           2014  117384.68     yes

# %%
a_trocar = {
    "no": 0,
    "yes": 1
}
dados.vendido = dados.vendido.map(a_trocar)
dados.head()
# Out:
#    Unnamed: 0  milhas_por_ano  ano_do_modelo      preco  vendido
# 0           0           21801           2000   30941.02        1
# 1           1            7843           1998   40557.96        1
# 2           2            7109           2006   89627.50        0
# 3           3           26823           2015   95276.14        0
# 4           4            7935           2014  117384.68        1

# %%
dados.head()
# Out:
#    Unnamed: 0  milhas_por_ano  ano_do_modelo      preco  vendido
# 0           0           21801           2000   30941.02        1
# 1           1            7843           1998   40557.96        1
# 2           2            7109           2006   89627.50        0
# 3           3           26823           2015   95276.14        0
# 4           4            7935           2014  117384.68        1

# %%
from datetime import datetime

ano_atual = datetime.today().year
dados['idade_do_modelo'] = ano_atual - dados.ano_do_modelo
dados.head()
# Out:
#    Unnamed: 0  milhas_por_ano  ano_do_modelo      preco  vendido  \
# 0           0           21801           2000   30941.02        1
# 1           1            7843           1998   40557.96        1
# 2           2            7109           2006   89627.50        0
# 3           3           26823           2015   95276.14        0
# 4           4            7935           2014  117384.68        1
#
#    idade_do_modelo
# 0               23
# 1               25
# 2               17
# 3                8
# 4                9

# %%
#agora transformar milhas em km
dados['km_por_ano'] = dados.milhas_por_ano * 1.60934
dados.head()
# Out:
#    Unnamed: 0  milhas_por_ano  ano_do_modelo      preco  vendido  \
# 0           0           21801           2000   30941.02        1
# 1           1            7843           1998   40557.96        1
# 2           2            7109           2006   89627.50        0
# 3           3           26823           2015   95276.14        0
# 4           4            7935           2014  117384.68        1
#
#    idade_do_modelo   km_por_ano
# 0               23  35085.22134
# 1               25  12622.05362
# 2               17  11440.79806
# 3                8  43167.32682
# 4                9  12770.11290
